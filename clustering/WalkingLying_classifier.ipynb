# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../')
# from dfHelper import*

# %%
subjects = [1,2,3,4]
runs = [1,2,3,4,5]
data = pd.DataFrame()
for subject in subjects:
    for run in runs:
        d = load_data_adl(subject, run, '../OpportunityUCIDataset')
        df_LW = get_locomotion_data(d, [2, 5])
        lie_walk = get_sensor_data(df_LW, 'all')
        data = data.append(lie_walk)

#walk is label 2, lie is label 5, change to 0,1
data['Locomotion'] = data['Locomotion'].replace(2, 0)
data['Locomotion'] = data['Locomotion'].replace(5, 1)

train_data = data[:int(len(data)*0.5)]
val_data = data[int(len(data)*0.5):int(len(data)*0.75)]
test_data = data[int(len(data)*0.75):]
# Out:
# /var/folders/gq/gwfhyzf925b2_vdp2wp5svf00000gr/T/ipykernel_66825/3742062296.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(get_locomotion(data, locs[i]))
# /var/folders/gq/gwfhyzf925b2_vdp2wp5svf00000gr/T/ipykernel_66825/3742062296.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acc_data[newheader] = np.sqrt(x**2 + y**2 + z**2)
# /var/folders/gq/gwfhyzf925b2_vdp2wp5svf00000gr/T/ipykernel_66825/3742062296.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
